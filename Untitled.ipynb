# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

import time

# %%
# 1. Add the clean movie function that takes in the argument, "movie".
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune-Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %%
file_dir = 'C://Users/keistlec/Desktop/PI/Columbia_Class/Movies-ETL/' 
wiki_file = f'{file_dir}wikipedia-movies.json'
with open(wiki_file, mode='r') as file:
        wiki_movies_raw = json.load(file)

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('No. of episodes' not in movie)]

# %%
wiki_movies_df = pd.DataFrame(wiki_movies)

# %%
wiki_movies_df
# Out:
#                                                     url    year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
# ...                                                 ...     ...
# 7300    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018.0
# 7301     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018.0
# 7302  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018.0
# 7303  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018.0
# 7304  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018.0
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7300  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7301  https://www.imdb.com/title/tt6266538/                             Vice
# 7302  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7303  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7304  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#              Directed by                                        Produced by  \
# 0           Renny Harlin                         [Steve Perry, Joel Silver]
# 1            James Foley                        [Ric Kidney, Robert Redlin]
# 2     Roger Spottiswoode                                     Daniel Melnick
# 3            Woody Allen                                    Robert Greenhut
# 4           John Cornell                                       John Cornell
# ...                  ...                                                ...
# 7300          Etan Cohen  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7301          Adam McKay  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7302          Mimi Leder                                     Robert W. Cort
# 7303        Karyn Kusama             [Fred Berger, Phil Hay, Matt Manfredi]
# 7304         David Slade                                     Russell McLean
#
#                                    Screenplay by                     Story by  \
# 0     [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                   [James Foley, Robert Redlin]                          NaN
# 2                     [John Eskow, Richard Rush]                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 7300                                  Etan Cohen                          NaN
# 7301                                         NaN                          NaN
# 7302                                         NaN                          NaN
# 7303                                         NaN                          NaN
# 7304                                         NaN                          NaN
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7300  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7301                                                NaN
# 7302                                                NaN
# 7303                                                NaN
# 7304                                                NaN
#
#                                                Starring  ... Predecessor  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...         NaN
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...  ...         NaN
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...         NaN
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...         NaN
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...         NaN
# ...                                                 ...  ...         ...
# 7300  [Will Ferrell, John C. Reilly, Rebecca Hall, R...  ...         NaN
# 7301  [Christian Bale, Amy Adams, Steve Carell, Sam ...  ...         NaN
# 7302  [Felicity Jones, Armie Hammer, Justin Theroux,...  ...         NaN
# 7303  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...         NaN
# 7304  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...         NaN
#
#      Founders Area served Products Services Russian Hebrew Revenue  \
# 0         NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1         NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2         NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3         NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4         NaN         NaN      NaN      NaN     NaN    NaN     NaN
# ...       ...         ...      ...      ...     ...    ...     ...
# 7300      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7301      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7302      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7303      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7304      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#      Operating income Polish
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2                 NaN    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
# ...               ...    ...
# 7300              NaN    NaN
# 7301              NaN    NaN
# 7302              NaN    NaN
# 7303              NaN    NaN
# 7304              NaN    NaN
#
# [7305 rows x 187 columns]

# %%
imdb_ids = wiki_movies_df['imdb_link'].dropna()

# %%
def is_not_a_string(x):
    return type(x) != str
imdb_ids[imdb_ids.map(is_not_a_string)]
# Out:
# Series([], Name: imdb_link, dtype: object)

# %%
imdb_ids
# Out:
# 0       https://www.imdb.com/title/tt0098987/
# 1       https://www.imdb.com/title/tt0098994/
# 2       https://www.imdb.com/title/tt0099005/
# 3       https://www.imdb.com/title/tt0099012/
# 4       https://www.imdb.com/title/tt0099018/
#                         ...
# 7300    https://www.imdb.com/title/tt1255919/
# 7301    https://www.imdb.com/title/tt6266538/
# 7302    https://www.imdb.com/title/tt4669788/
# 7303    https://www.imdb.com/title/tt7137380/
# 7304    https://www.imdb.com/title/tt9495224/
# Name: imdb_link, Length: 7094, dtype: object

# %%
p = '(tt\d{7})'
wiki_movies_df['imdb_link'].str.extract(p, flags=re.I)
# Out:
#               0
# 0     tt0098987
# 1     tt0098994
# 2     tt0099005
# 3     tt0099012
# 4     tt0099018
# ...         ...
# 7300  tt1255919
# 7301  tt6266538
# 7302  tt4669788
# 7303  tt7137380
# 7304  tt9495224
#
# [7305 rows x 1 columns]

# %%
    # 6. Write a try-except block to catch errors while extracting the IMDb ID using a regular expression string 
    # and dropping any imdb_id duplicates. If there is an error, capture and print the exception.
try:  
        wiki_movies_df['imdb_link'].str.extract('(tt\d{7})', flags=re.I)
        wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
except Exception as e: print(e)
# Out:
# Index(['imdb_id'], dtype='object')

# %%
[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 158],
#  ['year', 158],
#  ['imdb_link', 211],
#  ['title', 177],
#  ['Directed by', 206],
#  ['Produced by', 565],
#  ['Screenplay by', 4982],
#  ['Story by', 6300],
#  ['Based on', 5108],
#  ['Starring', 389],
#  ['Narrated by', 7021],
#  ['Music by', 802],
#  ['Cinematography', 908],
#  ['Edited by', 907],
#  ['Productioncompany ', 2765],
#  ['Distributed by', 706],
#  ['Release date', 391],
#  ['Running time', 342],
#  ['Country', 579],
#  ['Language', 432],
#  ['Budget', 2531],
#  ['Box office', 1775],
#  ['Written by', 2709],
#  ['Genre', 7181],
#  ['Theme music composer', 7238],
#  ['Country of origin', 7153],
#  ['Original language(s)', 7147],
#  ['Producer(s)', 7148],
#  ['Editor(s)', 7159],
#  ['Production company(s)', 7174],
#  ['Original network', 7180],
#  ['Original release', 7146],
#  ['Productioncompanies ', 6576],
#  ['Executive producer(s)', 7208],
#  ['Production location(s)', 7258],
#  ['Distributor', 7167],
#  ['Picture format', 7241],
#  ['Audio format', 7244],
#  ['Voices of', 7303],
#  ['Followed by', 7291],
#  ['Composer(s)', 7296],
#  ['Created by', 7293],
#  ['Preceded by', 7289],
#  ['Author', 7293],
#  ['Publisher', 7293],
#  ['Publication date', 7294],
#  ['Media type', 7296],
#  ['Pages', 7298],
#  ['ISBN', 7300],
#  ['OCLC', 7299],
#  ['LC Class', 7300],
#  ['Cover artist', 7302],
#  ['Series', 7302],
#  ['Set in', 7303],
#  ['Adaptation by', 7303],
#  ['Suggested by', 7304],
#  ['Biographical data', 7304],
#  ['Born', 7297],
#  ['Died', 7304],
#  ['Resting place', 7304],
#  ['Occupation', 7297],
#  ['Years active', 7299],
#  ['Spouse(s)', 7304],
#  ['Children', 7304],
#  ['Parent(s)', 7303],
#  ['Genres', 7304],
#  ['Instruments', 7304],
#  ['Labels', 7304],
#  ['Website', 7298],
#  ['Traditional', 7300],
#  ['Mandarin', 7301],
#  ['Type', 7299],
#  ['Industry', 7300],
#  ['Fate', 7304],
#  ['Founded', 7299],
#  ['Founder', 7302],
#  ['Headquarters', 7299],
#  ['Parent', 7303],
#  ['Released', 7301],
#  ['Recorded', 7302],
#  ['Venue', 7304],
#  ['Length', 7302],
#  ['Label', 7301],
#  ['Director', 7303],
#  ['Producer', 7302],
#  ['Area', 7304],
#  ['Coordinates', 7304],
#  ['Status', 7304],
#  ['Opening date', 7304],
#  ['Closing date', 7304],
#  ['Replaced', 7304],
#  ['Replaced by', 7304],
#  ['Name', 7304],
#  ['Attraction type', 7304],
#  ['Music', 7304],
#  ['Duration', 7304],
#  ['Simplified Chinese', 7304],
#  ['Traditional Chinese', 7304],
#  ['Hanyu Pinyin', 7304],
#  ['Literal meaning', 7304],
#  ['Transcriptions', 7304],
#  ['Bopomofo', 7304],
#  ['Gwoyeu Romatzyh', 7304],
#  ['Wade–Giles', 7304],
#  ['IPA', 7304],
#  ['Yale Romanization', 7304],
#  ['Jyutping', 7304],
#  ['Hokkien POJ', 7304],
#  ['Also known as', 7304],
#  ['Animation by', 7303],
#  ['Color process', 7304],
#  ['Engine(s)', 7304],
#  ['Genre(s)', 7303],
#  ['Actor control', 7304],
#  ['Production company', 7304],
#  ['Release(s)', 7304],
#  ['Format(s)', 7304],
#  ['Simplified', 7301],
#  ['Characters', 7303],
#  ['Date premiered', 7302],
#  ['Place premiered', 7302],
#  ['Setting', 7303],
#  ['Original language', 7303],
#  ['Subject', 7303],
#  ['Published', 7304],
#  ['Dewey Decimal', 7301],
#  ['Text', 7303],
#  ['Illustrator', 7302],
#  ['Original title', 7303],
#  ['Published in English', 7304],
#  ['French', 7304],
#  ['Nationality', 7302],
#  ['Portrayed by', 7304],
#  ['Alias', 7304],
#  ['Species', 7304],
#  ['Gender', 7304],
#  ['Family', 7304],
#  ['Alma mater', 7303],
#  ['Novel(s)', 7304],
#  ['Comics', 7304],
#  ['Film(s)', 7303],
#  ['Screen story by', 7304],
#  ['Hangul', 7303],
#  ['Revised Romanization', 7303],
#  ['McCune–Reischauer', 7303],
#  ['Developer(s)', 7304],
#  ['Publisher(s)', 7304],
#  ['Designer(s)', 7304],
#  ['Programmer(s)', 7304],
#  ['Artist(s)', 7304],
#  ['Writer(s)', 7304],
#  ['Engine', 7304],
#  ['Platform(s)', 7304],
#  ['Release', 7304],
#  ['Mode(s)', 7304],
#  ['Original work', 7304],
#  ['Television series', 7304],
#  ['Japanese', 7301],
#  ['Hepburn', 7301],
#  ['Literally', 7302],
#  ['Cantonese', 7304],
#  ['Full name', 7304],
#  ['Height', 7303],
#  ['Seasons', 7304],
#  ['Chinese', 7304],
#  ['Other names', 7304],
#  ['Relatives', 7304],
#  ['Yiddish', 7304],
#  ['Formerly', 7301],
#  ['Key people', 7301],
#  ['Total assets', 7304],
#  ['Owner', 7301],
#  ['Number of employees', 7303],
#  ['Divisions', 7301],
#  ['Subsidiaries', 7301],
#  ['Arabic', 7303],
#  ['Romanized', 7303],
#  ['Predecessor', 7302],
#  ['Founders', 7302],
#  ['Area served', 7302],
#  ['Products', 7302],
#  ['Services', 7303],
#  ['Russian', 7304],
#  ['Hebrew', 7304],
#  ['Revenue', 7304],
#  ['Operating income', 7304],
#  ['Polish', 7304]]

# %%
[column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by']
